# %%
from collections import defaultdict
import itertools
import os
import pandas as pd
import matplotlib.pyplot as plt 
import numpy as np
from IPython.display import Markdown
from matminer.datasets import load_dataset, get_all_dataset_info
from pymatgen.core import Composition

from modnet.preprocessing import MODData
from modnet.featurizers import MODFeaturizer
from modnet.featurizers.presets import DeBreuck2020Featurizer

# %%
df = load_dataset('matbench_expt_gap')
df['composition'] = df['composition'].map(Composition)
df
# Out:
#            composition  gap expt
# 0          (Ag, Au, S)      0.00
# 1          (Ag, W, Br)      0.00
# 2      (Ag, Ge, Pb, S)      1.83
# 3     (Ag, Ge, Pb, Se)      1.51
# 4          (Ag, B, Br)      0.00
# ...                ...       ...
# 4599       (Zr, Ta, N)      1.72
# 4600          (Zr, Te)      0.00
# 4601       (Zr, Ti, O)      0.00
# 4602       (Zr, Ti, F)      0.00
# 4603           (Zr, W)      0.00
#
# [4604 rows x 2 columns]

# %%
from matminer.featurizers.composition import ElementProperty

matscholar = ElementProperty.from_preset('matscholar_el')
feat = ElementProperty(matscholar.data_source, matscholar.features, stats=['mean', 'std_dev'])
feat_df = pd.DataFrame(feat.transform(df['composition']), columns=feat.feature_labels()).select_dtypes('number')
feat_df
# Out:
#       MatscholarElementData mean embedding 1  \
# 0                                  -0.003591
# 1                                  -0.017097
# 2                                   0.026121
# 3                                   0.068723
# 4                                  -0.036843
# ...                                      ...
# 4599                               -0.065811
# 4600                                0.026611
# 4601                               -0.023105
# 4602                               -0.010181
# 4603                               -0.018409
#
#       MatscholarElementData std_dev embedding 1  \
# 0                                      0.057427
# 1                                      0.001886
# 2                                      0.060369
# 3                                      0.096610
# 4                                      0.050088
# ...                                         ...
# 4599                                   0.034929
# 4600                                   0.063109
# 4601                                   0.017138
# 4602                                   0.016565
# 4603                                   0.000419
#
#       MatscholarElementData mean embedding 2  \
# 0                                   0.035249
# 1                                  -0.011967
# 2                                  -0.001658
# 3                                   0.059994
# 4                                   0.028695
# ...                                      ...
# 4599                               -0.037832
# 4600                               -0.001758
# 4601                               -0.065338
# 4602                               -0.052636
# 4603                               -0.007942
#
#       MatscholarElementData std_dev embedding 2  \
# 0                                      0.083360
# 1                                      0.039746
# 2                                      0.065045
# 3                                      0.017914
# 4                                      0.064734
# ...                                         ...
# 4599                                   0.022494
# 4600                                   0.064243
# 4601                                   0.015014
# 4602                                   0.008669
# 4603                                   0.041623
#
#       MatscholarElementData mean embedding 3  \
# 0                                   0.011725
# 1                                   0.033914
# 2                                   0.030543
# 3                                  -0.010385
# 4                                   0.009536
# ...                                      ...
# 4599                                0.078252
# 4600                                0.036091
# 4601                                0.008387
# 4602                                0.085890
# 4603                                0.036247
#
#       MatscholarElementData std_dev embedding 3  \
# 0                                      0.034370
# 1                                      0.019850
# 2                                      0.027779
# 3                                      0.035647
# 4                                      0.045812
# ...                                         ...
# 4599                                   0.059726
# 4600                                   0.007541
# 4601                                   0.027283
# 4602                                   0.067159
# 4603                                   0.005490
#
#       MatscholarElementData mean embedding 4  \
# 0                                   0.021616
# 1                                   0.016558
# 2                                   0.051504
# 3                                   0.053803
# 4                                   0.050019
# ...                                      ...
# 4599                                0.007499
# 4600                                0.039583
# 4601                               -0.065576
# 4602                                0.076440
# 4603                               -0.039275
#
#       MatscholarElementData std_dev embedding 4  \
# 0                                      0.052416
# 1                                      0.064538
# 2                                      0.023307
# 3                                      0.025920
# 4                                      0.041757
# ...                                         ...
# 4599                                   0.054294
# 4600                                   0.072248
# 4601                                   0.079565
# 4602                                   0.140190
# 4603                                   0.029455
#
#       MatscholarElementData mean embedding 5  \
# 0                                   0.031669
# 1                                  -0.026530
# 2                                  -0.013456
# 3                                  -0.058548
# 4                                  -0.000367
# ...                                      ...
# 4599                               -0.032627
# 4600                               -0.069230
# 4601                               -0.057071
# 4602                                0.005393
# 4603                               -0.059334
#
#       MatscholarElementData std_dev embedding 5  ...  \
# 0                                      0.045029  ...
# 1                                      0.031111  ...
# 2                                      0.021123  ...
# 3                                      0.051351  ...
# 4                                      0.051653  ...
# ...                                         ...  ...
# 4599                                   0.030212  ...
# 4600                                   0.000061  ...
# 4601                                   0.013174  ...
# 4602                                   0.058058  ...
# 4603                                   0.010450  ...
#
#       MatscholarElementData mean embedding 196  \
# 0                                     0.040068
# 1                                     0.009553
# 2                                     0.025710
# 3                                     0.018905
# 4                                     0.016798
# ...                                        ...
# 4599                                  0.000830
# 4600                                 -0.015139
# 4601                                  0.016886
# 4602                                 -0.013365
# 4603                                  0.022134
#
#       MatscholarElementData std_dev embedding 196  \
# 0                                        0.048842
# 1                                        0.009222
# 2                                        0.051473
# 3                                        0.055868
# 4                                        0.018342
# ...                                           ...
# 4599                                     0.033519
# 4600                                     0.060341
# 4601                                     0.048513
# 4602                                     0.024270
# 4603                                     0.005722
#
#       MatscholarElementData mean embedding 197  \
# 0                                     0.024804
# 1                                     0.022442
# 2                                    -0.003740
# 3                                     0.023300
# 4                                     0.054368
# ...                                        ...
# 4599                                  0.007771
# 4600                                  0.020321
# 4601                                  0.021705
# 4602                                 -0.043544
# 4603                                  0.060271
#
#       MatscholarElementData std_dev embedding 197  \
# 0                                        0.033855
# 1                                        0.037096
# 2                                        0.029255
# 3                                        0.039493
# 4                                        0.039552
# ...                                           ...
# 4599                                     0.065592
# 4600                                     0.062876
# 4601                                     0.048863
# 4602                                     0.084062
# 4603                                     0.004784
#
#       MatscholarElementData mean embedding 198  \
# 0                                     0.111262
# 1                                     0.002889
# 2                                     0.081189
# 3                                     0.067591
# 4                                     0.075689
# ...                                        ...
# 4599                                  0.093478
# 4600                                  0.039449
# 4601                                  0.078352
# 4602                                  0.044121
# 4603                                  0.030207
#
#       MatscholarElementData std_dev embedding 198  \
# 0                                        0.028340
# 1                                        0.046974
# 2                                        0.040458
# 3                                        0.041128
# 4                                        0.087409
# ...                                           ...
# 4599                                     0.044513
# 4600                                     0.053558
# 4601                                     0.009439
# 4602                                     0.033574
# 4603                                     0.049971
#
#       MatscholarElementData mean embedding 199  \
# 0                                    -0.003313
# 1                                    -0.048617
# 2                                     0.016426
# 3                                    -0.085493
# 4                                    -0.041892
# ...                                        ...
# 4599                                  0.003102
# 4600                                 -0.053556
# 4601                                 -0.031303
# 4602                                  0.028537
# 4603                                 -0.024603
#
#       MatscholarElementData std_dev embedding 199  \
# 0                                        0.061645
# 1                                        0.011682
# 2                                        0.053277
# 3                                        0.069807
# 4                                        0.059353
# ...                                           ...
# 4599                                     0.049275
# 4600                                     0.083282
# 4601                                     0.029489
# 4602                                     0.051811
# 4603                                     0.031753
#
#       MatscholarElementData mean embedding 200  \
# 0                                     0.054466
# 1                                     0.010825
# 2                                     0.032452
# 3                                     0.031954
# 4                                     0.063164
# ...                                        ...
# 4599                                 -0.035063
# 4600                                  0.042594
# 4601                                  0.034271
# 4602                                  0.022088
# 4603                                  0.076087
#
#       MatscholarElementData std_dev embedding 200
# 0                                        0.042503
# 1                                        0.079961
# 2                                        0.052363
# 3                                        0.052091
# 4                                        0.077328
# ...                                           ...
# 4599                                     0.090402
# 4600                                     0.029055
# 4601                                     0.034546
# 4602                                     0.028930
# 4603                                     0.013734
#
# [4604 rows x 400 columns]

# %%
combo_df = pd.concat([feat_df, df], axis=1).select_dtypes('number')
display(combo_df)
combo_df.to_feather('datasets/mb_expt_gap.feather')
# Out:
#       MatscholarElementData mean embedding 1  \
# 0                                  -0.003591
# 1                                  -0.017097
# 2                                   0.026121
# 3                                   0.068723
# 4                                  -0.036843
# ...                                      ...
# 4599                               -0.065811
# 4600                                0.026611
# 4601                               -0.023105
# 4602                               -0.010181
# 4603                               -0.018409
#
#       MatscholarElementData std_dev embedding 1  \
# 0                                      0.057427
# 1                                      0.001886
# 2                                      0.060369
# 3                                      0.096610
# 4                                      0.050088
# ...                                         ...
# 4599                                   0.034929
# 4600                                   0.063109
# 4601                                   0.017138
# 4602                                   0.016565
# 4603                                   0.000419
#
#       MatscholarElementData mean embedding 2  \
# 0                                   0.035249
# 1                                  -0.011967
# 2                                  -0.001658
# 3                                   0.059994
# 4                                   0.028695
# ...                                      ...
# 4599                               -0.037832
# 4600                               -0.001758
# 4601                               -0.065338
# 4602                               -0.052636
# 4603                               -0.007942
#
#       MatscholarElementData std_dev embedding 2  \
# 0                                      0.083360
# 1                                      0.039746
# 2                                      0.065045
# 3                                      0.017914
# 4                                      0.064734
# ...                                         ...
# 4599                                   0.022494
# 4600                                   0.064243
# 4601                                   0.015014
# 4602                                   0.008669
# 4603                                   0.041623
#
#       MatscholarElementData mean embedding 3  \
# 0                                   0.011725
# 1                                   0.033914
# 2                                   0.030543
# 3                                  -0.010385
# 4                                   0.009536
# ...                                      ...
# 4599                                0.078252
# 4600                                0.036091
# 4601                                0.008387
# 4602                                0.085890
# 4603                                0.036247
#
#       MatscholarElementData std_dev embedding 3  \
# 0                                      0.034370
# 1                                      0.019850
# 2                                      0.027779
# 3                                      0.035647
# 4                                      0.045812
# ...                                         ...
# 4599                                   0.059726
# 4600                                   0.007541
# 4601                                   0.027283
# 4602                                   0.067159
# 4603                                   0.005490
#
#       MatscholarElementData mean embedding 4  \
# 0                                   0.021616
# 1                                   0.016558
# 2                                   0.051504
# 3                                   0.053803
# 4                                   0.050019
# ...                                      ...
# 4599                                0.007499
# 4600                                0.039583
# 4601                               -0.065576
# 4602                                0.076440
# 4603                               -0.039275
#
#       MatscholarElementData std_dev embedding 4  \
# 0                                      0.052416
# 1                                      0.064538
# 2                                      0.023307
# 3                                      0.025920
# 4                                      0.041757
# ...                                         ...
# 4599                                   0.054294
# 4600                                   0.072248
# 4601                                   0.079565
# 4602                                   0.140190
# 4603                                   0.029455
#
#       MatscholarElementData mean embedding 5  \
# 0                                   0.031669
# 1                                  -0.026530
# 2                                  -0.013456
# 3                                  -0.058548
# 4                                  -0.000367
# ...                                      ...
# 4599                               -0.032627
# 4600                               -0.069230
# 4601                               -0.057071
# 4602                                0.005393
# 4603                               -0.059334
#
#       MatscholarElementData std_dev embedding 5  ...  \
# 0                                      0.045029  ...
# 1                                      0.031111  ...
# 2                                      0.021123  ...
# 3                                      0.051351  ...
# 4                                      0.051653  ...
# ...                                         ...  ...
# 4599                                   0.030212  ...
# 4600                                   0.000061  ...
# 4601                                   0.013174  ...
# 4602                                   0.058058  ...
# 4603                                   0.010450  ...
#
#       MatscholarElementData std_dev embedding 196  \
# 0                                        0.048842
# 1                                        0.009222
# 2                                        0.051473
# 3                                        0.055868
# 4                                        0.018342
# ...                                           ...
# 4599                                     0.033519
# 4600                                     0.060341
# 4601                                     0.048513
# 4602                                     0.024270
# 4603                                     0.005722
#
#       MatscholarElementData mean embedding 197  \
# 0                                     0.024804
# 1                                     0.022442
# 2                                    -0.003740
# 3                                     0.023300
# 4                                     0.054368
# ...                                        ...
# 4599                                  0.007771
# 4600                                  0.020321
# 4601                                  0.021705
# 4602                                 -0.043544
# 4603                                  0.060271
#
#       MatscholarElementData std_dev embedding 197  \
# 0                                        0.033855
# 1                                        0.037096
# 2                                        0.029255
# 3                                        0.039493
# 4                                        0.039552
# ...                                           ...
# 4599                                     0.065592
# 4600                                     0.062876
# 4601                                     0.048863
# 4602                                     0.084062
# 4603                                     0.004784
#
#       MatscholarElementData mean embedding 198  \
# 0                                     0.111262
# 1                                     0.002889
# 2                                     0.081189
# 3                                     0.067591
# 4                                     0.075689
# ...                                        ...
# 4599                                  0.093478
# 4600                                  0.039449
# 4601                                  0.078352
# 4602                                  0.044121
# 4603                                  0.030207
#
#       MatscholarElementData std_dev embedding 198  \
# 0                                        0.028340
# 1                                        0.046974
# 2                                        0.040458
# 3                                        0.041128
# 4                                        0.087409
# ...                                           ...
# 4599                                     0.044513
# 4600                                     0.053558
# 4601                                     0.009439
# 4602                                     0.033574
# 4603                                     0.049971
#
#       MatscholarElementData mean embedding 199  \
# 0                                    -0.003313
# 1                                    -0.048617
# 2                                     0.016426
# 3                                    -0.085493
# 4                                    -0.041892
# ...                                        ...
# 4599                                  0.003102
# 4600                                 -0.053556
# 4601                                 -0.031303
# 4602                                  0.028537
# 4603                                 -0.024603
#
#       MatscholarElementData std_dev embedding 199  \
# 0                                        0.061645
# 1                                        0.011682
# 2                                        0.053277
# 3                                        0.069807
# 4                                        0.059353
# ...                                           ...
# 4599                                     0.049275
# 4600                                     0.083282
# 4601                                     0.029489
# 4602                                     0.051811
# 4603                                     0.031753
#
#       MatscholarElementData mean embedding 200  \
# 0                                     0.054466
# 1                                     0.010825
# 2                                     0.032452
# 3                                     0.031954
# 4                                     0.063164
# ...                                        ...
# 4599                                 -0.035063
# 4600                                  0.042594
# 4601                                  0.034271
# 4602                                  0.022088
# 4603                                  0.076087
#
#       MatscholarElementData std_dev embedding 200  gap expt
# 0                                        0.042503      0.00
# 1                                        0.079961      0.00
# 2                                        0.052363      1.83
# 3                                        0.052091      1.51
# 4                                        0.077328      0.00
# ...                                           ...       ...
# 4599                                     0.090402      1.72
# 4600                                     0.029055      0.00
# 4601                                     0.034546      0.00
# 4602                                     0.028930      0.00
# 4603                                     0.013734      0.00
#
# [4604 rows x 401 columns]
